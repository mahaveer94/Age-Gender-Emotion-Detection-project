# %% [markdown]
# ## Plan of Action
#
# *   **CK+ Dataset images** are stored **in separate folders,** named basis their emotion labels:
#  *   0 = 'anger', 1 = 'contempt',  2 = 'disgust',    3 = 'fear',    4 = 'happy',    5 = 'sadness',    6 = 'surprise'
#
# * Convert all images to **grayscale**
# * **Define emotion labels** basis use case
# * Using **X epochs** on our **defined CNN Architecture**, comprising of:
#     - an input *Conv2D* layer (with 32 filters) paired with an *MaxPooling2D* layer,
#     - 3 pairs of *Conv2D* (with 64, 128 & 256 filters) and *MaxPooling2D* layers,
#     - 1 *Dense* layer with 128 nodes, and
#     - an output *Dense* layer with 3 nodes.

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project5_AgeGenderEmotion_Detection/1.3_emotion_input_output
# !ls
# Out:
# /content/drive/MyDrive/Project5_AgeGenderEmotion_Detection/1.3_emotion_input_output
# input  output

# %% [markdown]
# # Import Libraties/ Functions

# %%
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split

import os
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten,BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D,Conv2D
from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd

from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPool2D,Dense,Dropout,BatchNormalization,Flatten,Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Import Dataset

# %%
dataset_folder='/content/drive/MyDrive/Project5_AgeGenderEmotion_Detection/1.3_emotion_input_output/input/CK+48'
sub_folders=os.listdir(dataset_folder)

sub_folders
# Out:
# ['surprise', 'contempt', 'anger', 'fear', 'sadness', 'disgust', 'happy']

# %%
images_x = np.array(images)
labels_y = np.array(labels)

# we divide image pixels by 255 to reduce computation power
images_x = images_x/255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-32c931f1c07c> in <cell line: 1>()
# ----> 1 images_x = np.array(images)
#       2 labels_y = np.array(labels)
#       3
#       4 # we divide image pixels by 255 to reduce computation power
#       5 images_x = images_x/255
#
# NameError: name 'images' is not defined

# %%
images_x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-12fc28fef83d> in <cell line: 1>()
# ----> 1 images_x.shape
#
# NameError: name 'images_x' is not defined

# %%
# encoding the labels
num_of_classes = 3
labels_y_encoded = tf.keras.utils.to_categorical(labels_y,num_classes=num_of_classes)

# %% [markdown]
# # Split into Train / Test

# %%
X_train, X_test, Y_train, Y_test= train_test_split(images_x, labels_y_encoded,test_size=0.25, random_state=10)

# %%
len(X_train)
# Out:
# 735

# %%
len(X_test)
# Out:
# 246

# %% [markdown]
# # Define CNN Architecture

# %%
input = Input(shape = (48,48,1))

conv1 = Conv2D(32,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(input)
conv1 = Dropout(0.1)(conv1)
conv1 = Activation('relu')(conv1)
pool1 = MaxPooling2D(pool_size = (2,2)) (conv1)

conv2 = Conv2D(64,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool1)
conv2 = Dropout(0.1)(conv2)
conv2 = Activation('relu')(conv2)
pool2 = MaxPooling2D(pool_size = (2,2)) (conv2)

conv3 = Conv2D(128,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool2)
conv3 = Dropout(0.1)(conv3)
conv3 = Activation('relu')(conv3)
pool3 = MaxPooling2D(pool_size = (2,2)) (conv3)

conv4 = Conv2D(256,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool3)
conv4 = Dropout(0.1)(conv4)
conv4 = Activation('relu')(conv4)
pool4 = MaxPooling2D(pool_size = (2,2)) (conv4)

flatten = Flatten()(pool4)

dense_1 = Dense(128,activation='relu')(flatten)

drop_1 = Dropout(0.2)(dense_1)

output = Dense(3,activation="sigmoid")(drop_1)

# %%
model = Model(inputs=input,outputs=output)
model.compile(optimizer="adam", loss=["categorical_crossentropy"], metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 32)        320
#
#  dropout_5 (Dropout)         (None, 48, 48, 32)        0
#
#  activation_4 (Activation)   (None, 48, 48, 32)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 64)        18496
#
#  dropout_6 (Dropout)         (None, 24, 24, 64)        0
#
#  activation_5 (Activation)   (None, 24, 24, 64)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  dropout_7 (Dropout)         (None, 12, 12, 128)       0
#
#  activation_6 (Activation)   (None, 12, 12, 128)       0
#
#  max_pooling2d_6 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)         295168
#
#  dropout_8 (Dropout)         (None, 6, 6, 256)         0
#
#  activation_7 (Activation)   (None, 6, 6, 256)         0
#
#  max_pooling2d_7 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 128)               295040
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 683267 (2.61 MB)
# Trainable params: 683267 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
fle_s='./output/emotion_model.h5'
checkpointer = ModelCheckpoint(fle_s, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %%
save = model.fit(X_train,Y_train,batch_size=32,validation_data=(X_test,Y_test),epochs=50,callbacks=[callback_list])
# Out:
# Epoch 1/50
# 23/23 [==============================] - ETA: 0s - loss: 1.3162 - accuracy: 0.4286
# Epoch 1: loss improved from inf to 1.31622, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 10s 331ms/step - loss: 1.3162 - accuracy: 0.4286 - val_loss: 1.2501 - val_accuracy: 0.4187
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 23/23 [==============================] - ETA: 0s - loss: 1.2097 - accuracy: 0.4395
# Epoch 2: loss improved from 1.31622 to 1.20971, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 5s 238ms/step - loss: 1.2097 - accuracy: 0.4395 - val_loss: 1.1729 - val_accuracy: 0.4187
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 1.1514 - accuracy: 0.4395
# Epoch 3: loss improved from 1.20971 to 1.15141, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 7s 328ms/step - loss: 1.1514 - accuracy: 0.4395 - val_loss: 1.1432 - val_accuracy: 0.4187
# Epoch 4/50
# 23/23 [==============================] - ETA: 0s - loss: 1.1142 - accuracy: 0.4395
# Epoch 4: loss improved from 1.15141 to 1.11422, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 244ms/step - loss: 1.1142 - accuracy: 0.4395 - val_loss: 1.0816 - val_accuracy: 0.4512
# Epoch 5/50
# 23/23 [==============================] - ETA: 0s - loss: 0.9425 - accuracy: 0.5701
# Epoch 5: loss improved from 1.11422 to 0.94252, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 265ms/step - loss: 0.9425 - accuracy: 0.5701 - val_loss: 0.9747 - val_accuracy: 0.5488
# Epoch 6/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8254 - accuracy: 0.6313
# Epoch 6: loss improved from 0.94252 to 0.82542, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 7s 288ms/step - loss: 0.8254 - accuracy: 0.6313 - val_loss: 0.7939 - val_accuracy: 0.6748
# Epoch 7/50
# 23/23 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.7102
# Epoch 7: loss improved from 0.82542 to 0.69972, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 261ms/step - loss: 0.6997 - accuracy: 0.7102 - val_loss: 0.7065 - val_accuracy: 0.7195
# Epoch 8/50
# 23/23 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.7605
# Epoch 8: loss improved from 0.69972 to 0.61086, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 9s 404ms/step - loss: 0.6109 - accuracy: 0.7605 - val_loss: 0.6828 - val_accuracy: 0.7805
# Epoch 9/50
# 23/23 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8327
# Epoch 9: loss improved from 0.61086 to 0.47491, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 247ms/step - loss: 0.4749 - accuracy: 0.8327 - val_loss: 0.5809 - val_accuracy: 0.7724
# Epoch 10/50
# 23/23 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8639
# Epoch 10: loss improved from 0.47491 to 0.40738, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 10s 433ms/step - loss: 0.4074 - accuracy: 0.8639 - val_loss: 0.4572 - val_accuracy: 0.8740
# Epoch 11/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8721
# Epoch 11: loss improved from 0.40738 to 0.37325, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 5s 232ms/step - loss: 0.3732 - accuracy: 0.8721 - val_loss: 0.4330 - val_accuracy: 0.8780
# Epoch 12/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9156
# Epoch 12: loss improved from 0.37325 to 0.29488, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 282ms/step - loss: 0.2949 - accuracy: 0.9156 - val_loss: 0.3413 - val_accuracy: 0.9228
# Epoch 13/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9510
# Epoch 13: loss improved from 0.29488 to 0.23011, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 271ms/step - loss: 0.2301 - accuracy: 0.9510 - val_loss: 0.2908 - val_accuracy: 0.9390
# Epoch 14/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9524
# Epoch 14: loss improved from 0.23011 to 0.21042, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 243ms/step - loss: 0.2104 - accuracy: 0.9524 - val_loss: 0.3192 - val_accuracy: 0.9065
# Epoch 15/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9483
# Epoch 15: loss did not improve from 0.21042
# 23/23 [==============================] - 8s 334ms/step - loss: 0.2227 - accuracy: 0.9483 - val_loss: 0.2346 - val_accuracy: 0.9715
# Epoch 16/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9646
# Epoch 16: loss improved from 0.21042 to 0.19388, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 5s 235ms/step - loss: 0.1939 - accuracy: 0.9646 - val_loss: 0.2439 - val_accuracy: 0.9675
# Epoch 17/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9837
# Epoch 17: loss improved from 0.19388 to 0.15351, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 8s 346ms/step - loss: 0.1535 - accuracy: 0.9837 - val_loss: 0.2019 - val_accuracy: 0.9715
# Epoch 18/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9878
# Epoch 18: loss improved from 0.15351 to 0.13632, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 5s 235ms/step - loss: 0.1363 - accuracy: 0.9878 - val_loss: 0.2263 - val_accuracy: 0.9715
# Epoch 19/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9850
# Epoch 19: loss did not improve from 0.13632
# 23/23 [==============================] - 6s 261ms/step - loss: 0.1393 - accuracy: 0.9850 - val_loss: 0.1741 - val_accuracy: 0.9797
# Epoch 20/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9823
# Epoch 20: loss did not improve from 0.13632
# 23/23 [==============================] - 7s 306ms/step - loss: 0.1529 - accuracy: 0.9823 - val_loss: 0.1822 - val_accuracy: 0.9634
# Epoch 21/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9905
# Epoch 21: loss improved from 0.13632 to 0.12583, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 8s 333ms/step - loss: 0.1258 - accuracy: 0.9905 - val_loss: 0.1792 - val_accuracy: 0.9837
# Epoch 22/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9796
# Epoch 22: loss did not improve from 0.12583
# 23/23 [==============================] - 7s 310ms/step - loss: 0.1362 - accuracy: 0.9796 - val_loss: 0.2197 - val_accuracy: 0.9634
# Epoch 23/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9646
# Epoch 23: loss did not improve from 0.12583
# 23/23 [==============================] - 5s 230ms/step - loss: 0.1794 - accuracy: 0.9646 - val_loss: 0.2504 - val_accuracy: 0.9390
# Epoch 24/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9741
# Epoch 24: loss did not improve from 0.12583
# 23/23 [==============================] - 7s 321ms/step - loss: 0.1627 - accuracy: 0.9741 - val_loss: 0.1717 - val_accuracy: 0.9837
# Epoch 25/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9837
# Epoch 25: loss did not improve from 0.12583
# 23/23 [==============================] - 6s 259ms/step - loss: 0.1422 - accuracy: 0.9837 - val_loss: 0.1950 - val_accuracy: 0.9878
# Epoch 26/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9946
# Epoch 26: loss improved from 0.12583 to 0.11510, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 7s 303ms/step - loss: 0.1151 - accuracy: 0.9946 - val_loss: 0.1773 - val_accuracy: 0.9797
# Epoch 27/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9986
# Epoch 27: loss improved from 0.11510 to 0.10495, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 242ms/step - loss: 0.1049 - accuracy: 0.9986 - val_loss: 0.1919 - val_accuracy: 0.9797
# Epoch 28/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9959
# Epoch 28: loss did not improve from 0.10495
# 23/23 [==============================] - 8s 359ms/step - loss: 0.1057 - accuracy: 0.9959 - val_loss: 0.1734 - val_accuracy: 0.9878
# Epoch 29/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9959
# Epoch 29: loss did not improve from 0.10495
# 23/23 [==============================] - 7s 307ms/step - loss: 0.1062 - accuracy: 0.9959 - val_loss: 0.1839 - val_accuracy: 0.9797
# Epoch 30/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9918
# Epoch 30: loss did not improve from 0.10495
# 23/23 [==============================] - 6s 244ms/step - loss: 0.1114 - accuracy: 0.9918 - val_loss: 0.1533 - val_accuracy: 0.9715
# Epoch 31/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9878
# Epoch 31: loss did not improve from 0.10495
# 23/23 [==============================] - 7s 317ms/step - loss: 0.1220 - accuracy: 0.9878 - val_loss: 0.1786 - val_accuracy: 0.9837
# Epoch 32/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 1.0000
# Epoch 32: loss improved from 0.10495 to 0.09989, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9837
# Epoch 33/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9905
# Epoch 33: loss did not improve from 0.09989
# 23/23 [==============================] - 7s 328ms/step - loss: 0.1083 - accuracy: 0.9905 - val_loss: 0.1392 - val_accuracy: 0.9797
# Epoch 34/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9986
# Epoch 34: loss did not improve from 0.09989
# 23/23 [==============================] - 6s 245ms/step - loss: 0.1000 - accuracy: 0.9986 - val_loss: 0.1415 - val_accuracy: 0.9878
# Epoch 35/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9959
# Epoch 35: loss improved from 0.09989 to 0.09680, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0968 - accuracy: 0.9959 - val_loss: 0.1503 - val_accuracy: 0.9878
# Epoch 36/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 1.0000
# Epoch 36: loss improved from 0.09680 to 0.08936, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9878
# Epoch 37/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 1.0000
# Epoch 37: loss improved from 0.08936 to 0.08700, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 5s 234ms/step - loss: 0.0870 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9878
# Epoch 38/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9932
# Epoch 38: loss did not improve from 0.08700
# 23/23 [==============================] - 8s 335ms/step - loss: 0.0935 - accuracy: 0.9932 - val_loss: 0.1531 - val_accuracy: 0.9878
# Epoch 39/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9959
# Epoch 39: loss did not improve from 0.08700
# 23/23 [==============================] - 5s 228ms/step - loss: 0.0915 - accuracy: 0.9959 - val_loss: 0.1216 - val_accuracy: 0.9919
# Epoch 40/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9959
# Epoch 40: loss did not improve from 0.08700
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0896 - accuracy: 0.9959 - val_loss: 0.1602 - val_accuracy: 0.9878
# Epoch 41/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9986
# Epoch 41: loss improved from 0.08700 to 0.08440, saving model to ./output/emotion_model.h5
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0844 - accuracy: 0.9986 - val_loss: 0.1811 - val_accuracy: 0.9715
# Epoch 42/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9932
# Epoch 42: loss did not improve from 0.08440
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0956 - accuracy: 0.9932 - val_loss: 0.1646 - val_accuracy: 0.9797
# Epoch 43/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9946
# Epoch 43: loss did not improve from 0.08440
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0971 - accuracy: 0.9946 - val_loss: 0.1748 - val_accuracy: 0.9715
# Epoch 44/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9932
# Epoch 44: loss did not improve from 0.08440
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0903 - accuracy: 0.9932 - val_loss: 0.1425 - val_accuracy: 0.9797
# Epoch 45/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9932
# Epoch 45: loss did not improve from 0.08440
# 23/23 [==============================] - 7s 327ms/step - loss: 0.0970 - accuracy: 0.9932 - val_loss: 0.1800 - val_accuracy: 0.9715
# Epoch 46/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9646
# Epoch 46: loss did not improve from 0.08440
# 23/23 [==============================] - 6s 243ms/step - loss: 0.1811 - accuracy: 0.9646 - val_loss: 0.2087 - val_accuracy: 0.9634
# Epoch 47/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9660
# Epoch 47: loss did not improve from 0.08440
# 23/23 [==============================] - 7s 314ms/step - loss: 0.1785 - accuracy: 0.9660 - val_loss: 0.1939 - val_accuracy: 0.9837
# Epoch 48/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9946
# Epoch 48: loss did not improve from 0.08440
# 23/23 [==============================] - 6s 247ms/step - loss: 0.1194 - accuracy: 0.9946 - val_loss: 0.1435 - val_accuracy: 0.9837
# Epoch 49/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9946
# Epoch 49: loss did not improve from 0.08440
# 23/23 [==============================] - 6s 245ms/step - loss: 0.1066 - accuracy: 0.9946 - val_loss: 0.2498 - val_accuracy: 0.9512
# Epoch 50/50
# 23/23 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9918
# Epoch 50: loss did not improve from 0.08440
# 23/23 [==============================] - 7s 321ms/step - loss: 0.1066 - accuracy: 0.9918 - val_loss: 0.1371 - val_accuracy: 0.9878

# %% [markdown]
# # Model Performance

# %%
# Checking the train and test loss and accuracy values from the neural network above.

train_loss = save.history['loss']
test_loss = save.history['val_loss']
train_accuracy = save.history['accuracy']
test_accuracy = save.history['val_accuracy']

# %%
# Plotting a line chart to visualize the loss and accuracy values by epochs.

fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')
