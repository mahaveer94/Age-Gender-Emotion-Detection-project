# %% [markdown]
# ## Plan of Action
#
# *   **UTK Face Dataset** images have labels embedded in their name, as per the following nomenclature:
#  * [age]\_[gender]\_[race]\_[time].jpg
# * **Import Gender Dataset** from Drive and **read gender labels** from file name
# * Convert all images to **grayscale**
# * Using **X epochs** on our **defined CNN Architecture**, comprising of:
#     - an input *Conv2D* layer (with 32 filters) paired with an *MaxPooling2D* layer,
#     - 3 pairs of *Conv2D* (with 64, 128 & 256 filters) and *MaxPooling2D* layers,
#     - 1 *Dense* layer with 128 nodes, and
#     - an output *Dense* layer with 3 nodes.

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project5_AgeGenderEmotion_Detection/1.2_gender_input_output
! ls
# Out:
# /content/drive/MyDrive/Project5_AgeGenderEmotion_Detection/1.2_gender_input_output
# input  output

# %% [markdown]
# ## Import Libraries/ Functions

# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
import os

import tensorflow as tf

from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPooling2D,AvgPool2D,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Flatten,Input
from sklearn.model_selection import train_test_split


from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Import Dataset

# %%
# Ref:  https://github.com/ChibaniMohamed/cnn_age_gender/blob/main/train.py

path = "./input/UTKFace"
pixels = []
age = []
gender = []

i=0
for img in os.listdir(path):
  i=i+1
  genders = img.split("_")[1]
  img = cv2.imread(str(path)+"/"+str(img))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img=cv2.resize(img,(100,100))
  pixels.append(np.array(img))
  gender.append(np.array(genders))

pixels = np.array(pixels)
gender = np.array(gender,np.uint64)

# %%
len(pixels)
# Out:
# 4765

# %%
len(gender)
# Out:
# 4765

# %% [markdown]
# ## Split into Train/ Test

# %%
x_train,x_test,y_train,y_test = train_test_split(pixels,gender,random_state=100)

# %%
len(x_train)
# Out:
# 3573

# %%
len(x_test)
# Out:
# 1192

# %% [markdown]
# ## Define CNN Architecture

# %%
input = Input(shape = (100,100,1))

conv1 = Conv2D(32,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(input)
conv1 = Dropout(0.1)(conv1)
conv1 = Activation('relu')(conv1)
pool1 = MaxPooling2D(pool_size = (2,2)) (conv1)

conv2 = Conv2D(64,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool1)
conv2 = Dropout(0.1)(conv2)
conv2 = Activation('relu')(conv2)
pool2 = MaxPooling2D(pool_size = (2,2)) (conv2)

conv3 = Conv2D(128,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool2)
conv3 = Dropout(0.1)(conv3)
conv3 = Activation('relu')(conv3)
pool3 = MaxPooling2D(pool_size = (2,2)) (conv3)

conv4 = Conv2D(256,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool3)
conv4 = Dropout(0.1)(conv4)
conv4 = Activation('relu')(conv4)
pool4 = MaxPooling2D(pool_size = (2,2)) (conv4)

flatten = Flatten()(pool4)

dense_1 = Dense(128,activation='relu')(flatten)

drop_1 = Dropout(0.2)(dense_1)

output = Dense(2,activation="sigmoid")(drop_1)

# %%
model = Model(inputs=input,outputs=output)
model.compile(optimizer="adam",loss=["sparse_categorical_crossentropy"],metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 100, 100, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 100, 100, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 100, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 100, 100, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 50, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 50, 50, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 50, 50, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 50, 50, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 25, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 25, 25, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 25, 25, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 25, 25, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,179,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,567,874 (5.98 MB)
#  Trainable params: 1,567,874 (5.98 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_path='./output/gender_model.keras'  # Change the file extension to '.keras'
checkpointer = ModelCheckpoint(model_path, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %%
model_path='./output/gender_model.h5'
checkpointer = ModelCheckpoint(model_path, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %% [markdown]
# ## Model Training

# %%
save = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=50,callbacks=[callback_list])
# Out:
# Epoch 1/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9692 - loss: 0.2173
# Epoch 1: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9690 - loss: 0.2180 - val_accuracy: 0.8633 - val_loss: 0.5125
# Epoch 2/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9644 - loss: 0.2268
# Epoch 2: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9644 - loss: 0.2271 - val_accuracy: 0.8490 - val_loss: 0.6692
# Epoch 3/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9591 - loss: 0.2452
# Epoch 3: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9592 - loss: 0.2445 - val_accuracy: 0.8532 - val_loss: 0.7433
# Epoch 4/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9705 - loss: 0.2046
# Epoch 4: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9705 - loss: 0.2048 - val_accuracy: 0.8473 - val_loss: 0.6015
# Epoch 5/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9757 - loss: 0.2097
# Epoch 5: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9754 - loss: 0.2102 - val_accuracy: 0.8440 - val_loss: 0.5004
# Epoch 6/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9646 - loss: 0.2209
# Epoch 6: loss did not improve from 0.21122
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9646 - loss: 0.2210 - val_accuracy: 0.8624 - val_loss: 0.5340
# Epoch 7/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9734 - loss: 0.2067
# Epoch 7: loss improved from 0.21122 to 0.20649, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9733 - loss: 0.2067 - val_accuracy: 0.8565 - val_loss: 0.5374
# Epoch 8/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9775 - loss: 0.1868
# Epoch 8: loss improved from 0.20649 to 0.19598, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9774 - loss: 0.1871 - val_accuracy: 0.8523 - val_loss: 0.6178
# Epoch 9/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9756 - loss: 0.2060
# Epoch 9: loss did not improve from 0.19598
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9755 - loss: 0.2061 - val_accuracy: 0.8532 - val_loss: 0.5583
# Epoch 10/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9719 - loss: 0.1952
# Epoch 10: loss improved from 0.19598 to 0.19544, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9719 - loss: 0.1952 - val_accuracy: 0.8658 - val_loss: 0.5774
# Epoch 11/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9729 - loss: 0.1971
# Epoch 11: loss did not improve from 0.19544
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9727 - loss: 0.1974 - val_accuracy: 0.8683 - val_loss: 0.5431
# Epoch 12/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9752 - loss: 0.1869
# Epoch 12: loss improved from 0.19544 to 0.19015, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9752 - loss: 0.1871 - val_accuracy: 0.8523 - val_loss: 0.5431
# Epoch 13/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9666 - loss: 0.1999
# Epoch 13: loss did not improve from 0.19015
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9668 - loss: 0.1997 - val_accuracy: 0.8557 - val_loss: 0.6005
# Epoch 14/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9778 - loss: 0.1906
# Epoch 14: loss improved from 0.19015 to 0.18878, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9778 - loss: 0.1906 - val_accuracy: 0.8666 - val_loss: 0.5394
# Epoch 15/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9791 - loss: 0.1699
# Epoch 15: loss improved from 0.18878 to 0.18071, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9790 - loss: 0.1703 - val_accuracy: 0.8314 - val_loss: 0.6555
# Epoch 16/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9752 - loss: 0.2009
# Epoch 16: loss did not improve from 0.18071
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9751 - loss: 0.2010 - val_accuracy: 0.8465 - val_loss: 0.5384
# Epoch 17/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9850 - loss: 0.1584
# Epoch 17: loss improved from 0.18071 to 0.17043, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9848 - loss: 0.1588 - val_accuracy: 0.8230 - val_loss: 0.6560
# Epoch 18/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9676 - loss: 0.1953
# Epoch 18: loss did not improve from 0.17043
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9678 - loss: 0.1950 - val_accuracy: 0.8565 - val_loss: 0.5366
# Epoch 19/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9828 - loss: 0.1541
# Epoch 19: loss did not improve from 0.17043
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9827 - loss: 0.1547 - val_accuracy: 0.8700 - val_loss: 0.5040
# Epoch 20/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9834 - loss: 0.1524
# Epoch 20: loss improved from 0.17043 to 0.15675, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9834 - loss: 0.1526 - val_accuracy: 0.8649 - val_loss: 0.5819
# Epoch 21/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9820 - loss: 0.1585
# Epoch 21: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9818 - loss: 0.1590 - val_accuracy: 0.8607 - val_loss: 0.5704
# Epoch 22/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9799 - loss: 0.1612
# Epoch 22: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9798 - loss: 0.1613 - val_accuracy: 0.8507 - val_loss: 0.5480
# Epoch 23/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9805 - loss: 0.1672
# Epoch 23: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9804 - loss: 0.1673 - val_accuracy: 0.8557 - val_loss: 0.5597
# Epoch 24/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9794 - loss: 0.1669
# Epoch 24: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9795 - loss: 0.1666 - val_accuracy: 0.8549 - val_loss: 0.5890
# Epoch 25/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9769 - loss: 0.1749
# Epoch 25: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9768 - loss: 0.1750 - val_accuracy: 0.8565 - val_loss: 0.5562
# Epoch 26/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9767 - loss: 0.1635
# Epoch 26: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9767 - loss: 0.1634 - val_accuracy: 0.8633 - val_loss: 0.6024
# Epoch 27/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9686 - loss: 0.1768
# Epoch 27: loss did not improve from 0.15675
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9689 - loss: 0.1764 - val_accuracy: 0.8591 - val_loss: 0.6486
# Epoch 28/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9859 - loss: 0.1404
# Epoch 28: loss improved from 0.15675 to 0.14814, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9858 - loss: 0.1407 - val_accuracy: 0.8515 - val_loss: 0.6936
# Epoch 29/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9754 - loss: 0.1814
# Epoch 29: loss did not improve from 0.14814
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9755 - loss: 0.1813 - val_accuracy: 0.8565 - val_loss: 0.5635
# Epoch 30/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9664 - loss: 0.1906
# Epoch 30: loss did not improve from 0.14814
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9666 - loss: 0.1903 - val_accuracy: 0.8574 - val_loss: 0.5472
# Epoch 31/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9899 - loss: 0.1401
# Epoch 31: loss improved from 0.14814 to 0.14189, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9898 - loss: 0.1401 - val_accuracy: 0.8591 - val_loss: 0.5642
# Epoch 32/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9826 - loss: 0.1533
# Epoch 32: loss did not improve from 0.14189
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9825 - loss: 0.1537 - val_accuracy: 0.8582 - val_loss: 0.5611
# Epoch 33/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9836 - loss: 0.1585
# Epoch 33: loss did not improve from 0.14189
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9836 - loss: 0.1584 - val_accuracy: 0.8607 - val_loss: 0.5359
# Epoch 34/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9895 - loss: 0.1291
# Epoch 34: loss improved from 0.14189 to 0.13637, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9894 - loss: 0.1294 - val_accuracy: 0.8372 - val_loss: 0.6368
# Epoch 35/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9805 - loss: 0.1494
# Epoch 35: loss did not improve from 0.13637
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9805 - loss: 0.1492 - val_accuracy: 0.8515 - val_loss: 0.6538
# Epoch 36/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9840 - loss: 0.1453
# Epoch 36: loss improved from 0.13637 to 0.13211, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9841 - loss: 0.1449 - val_accuracy: 0.8624 - val_loss: 0.7699
# Epoch 37/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9786 - loss: 0.1554
# Epoch 37: loss did not improve from 0.13211
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9786 - loss: 0.1552 - val_accuracy: 0.8456 - val_loss: 0.6468
# Epoch 38/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9776 - loss: 0.1650
# Epoch 38: loss did not improve from 0.13211
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9775 - loss: 0.1651 - val_accuracy: 0.8725 - val_loss: 0.5235
# Epoch 39/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9852 - loss: 0.1426
# Epoch 39: loss did not improve from 0.13211
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9851 - loss: 0.1429 - val_accuracy: 0.8574 - val_loss: 0.5412
# Epoch 40/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9865 - loss: 0.1312
# Epoch 40: loss did not improve from 0.13211
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9863 - loss: 0.1315 - val_accuracy: 0.8842 - val_loss: 0.4958
# Epoch 41/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9840 - loss: 0.1517
# Epoch 41: loss did not improve from 0.13211
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9840 - loss: 0.1517 - val_accuracy: 0.8742 - val_loss: 0.5989
# Epoch 42/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9891 - loss: 0.1252
# Epoch 42: loss improved from 0.13211 to 0.12886, saving model to ./output/gender_model.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9891 - loss: 0.1254 - val_accuracy: 0.8658 - val_loss: 0.5418
# Epoch 43/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9856 - loss: 0.1231
# Epoch 43: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9855 - loss: 0.1232 - val_accuracy: 0.8599 - val_loss: 0.5712
# Epoch 44/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9790 - loss: 0.1522
# Epoch 44: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9791 - loss: 0.1517 - val_accuracy: 0.8742 - val_loss: 0.6923
# Epoch 45/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9756 - loss: 0.1616
# Epoch 45: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9756 - loss: 0.1613 - val_accuracy: 0.8733 - val_loss: 0.5381
# Epoch 46/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9825 - loss: 0.1441
# Epoch 46: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9824 - loss: 0.1443 - val_accuracy: 0.8674 - val_loss: 0.5723
# Epoch 47/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9892 - loss: 0.1269
# Epoch 47: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9891 - loss: 0.1270 - val_accuracy: 0.8574 - val_loss: 0.5674
# Epoch 48/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9788 - loss: 0.1435
# Epoch 48: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9788 - loss: 0.1435 - val_accuracy: 0.8607 - val_loss: 0.5816
# Epoch 49/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9829 - loss: 0.1321
# Epoch 49: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9828 - loss: 0.1323 - val_accuracy: 0.8683 - val_loss: 0.6208
# Epoch 50/50
# 109/112 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9791 - loss: 0.1468
# Epoch 50: loss did not improve from 0.12886
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9790 - loss: 0.1474 - val_accuracy: 0.8624 - val_loss: 0.5028

# %%
# Checking the train and test loss and accuracy values from the neural network above.

train_loss = save.history['loss']
test_loss = save.history['val_loss']
train_accuracy = save.history['accuracy']
test_accuracy = save.history['val_accuracy']

# %%
# Plotting a line chart to visualize the loss and accuracy values by epochs.

fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')
